# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Practice Using APIs
#
# _Instructor: Aymeric Flaisler_
#
# ---
#
# In this lab we will practice using some popular APIs to retrieve and store data.

# %%
# Imports at the top
import json
import urllib
import pandas as pd
import numpy as np
import requests
import json
import re
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Exercise 1: get data from Sheetsu
#
# ---
#
# [Sheetsu](https://sheetsu.com/) is an online service that allows you to access any Google spreadsheet from an API. This can be a very powerful way to share a dataset with colleagues as well as to create a mini centralized data storage that is simpler to edit than a database.
#
# A Google Spreadsheet with Wine data can be found [here](https://docs.google.com/spreadsheets/d/1mZ3Otr5AV4v8WwvLOAvWf3VLxDa-IeJ1AVTEuavJqeo/).
#
# It can be accessed through sheetsu API at this endpoint: https://sheetsu.com/apis/v1.0/2899e32f4844
#
# **Questions:**
#
# 1. Use the requests library to access the document. Inspect the response text. What kind of data is it?
# - Check the status code of the response object. What code is it?
# - Use the appropriate libraries and read functions to read the response into a Pandas Dataframe.
# - Once you've imported the data into a dataframe, check the value of the 5th line: what's the price?

# %%
# You can either post or get info from this API
api_base_url = 'https://sheetsu.com/apis/v1.0su/4ce9c3459aad'

# %%
# A:
data=requests.get(api_base_url)

# %%
data.text
# Out:
# '{"error":"Too many rows."}'

# %%
data.status_code
# Out:
# 402

# %% [markdown]
# ## Exercise 2: post data to Sheetsu
#
# ---
#
# We've learned how to read data, but it'd be great if we could also write data. For this we will need to use a _POST_ request.
#
# 1. Use the post command to add the `post_data` to the spreadsheet.
# - What status did you get? How can you check that you actually added the data correctly?
# - In this exercise, your classmates are adding data to the same spreadsheet. What happens because of this? Is it a problem? How could you mitigate it?

# %%
post_data = {
'Grape' : ''
, 'Name' : 'My wonderful wine'
, 'Color' : 'R'
, 'Country' : 'US'
, 'Region' : 'Sonoma'
, 'Vinyard' : ''
, 'Score' : '10'
, 'Consumed In' : '2015'
, 'Vintage' : '1973'
, 'Price' : '200'
}

# %%
# A:

# %% [markdown]
# ## Exercise 3: IMDB TV Shows
#
# ---
#
# Sometimes an API doesn't provide all the information we would like to get and we need to be creative.
#
# Here we will use a combination of scraping and API calls to find the ratings and networks of famous television shows.

# %% [markdown]
# ### 3.A Get the top TV Shows
#
# The Internet Movie Database contains data about movies and TV shows. Unfortunately it does not have a public API.
#
# The page http://www.imdb.com/chart/toptv/?ref_=nv_tp_tv250_2 contains the list of the top 250 tv shows of all time. Retrieve the page using the requests library and then parse the html to obtain a list of the `movie_ids` for these movies. You can parse it with regular expression or using a library like `BeautifulSoup`.
#
# > **Hint:** movie_ids look like this: `tt2582802`
# > _Everything after "/title/" and before "/?"_

# %%
# A:
data2=requests.get('http://www.imdb.com/chart/toptv/?ref_=nv_tp_tv250_2')

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(data2.text)

# %%
counter=0
lst=[]
for link in soup.find_all('a'):
    tt=re.findall(r'/title/(.*)/',str(link.get('href')))
    if tt:
        counter+=1
        lst.append(tt[0])
        #print(tt)
    #print(link.text)
counter=0
final_lst=[]
for i in lst:
    counter+=1
    if counter%2 != 0:
        final_lst.append(i)
print(len(final_lst))
# Out:
# 251

# %%
#final_lst.pop(0)
#the first id is not included in the list of top 250 movies.
# Out:
# 'tt0245429'

# %% [markdown]
# ### 3.B Get data on the top movies
#
# Although the Internet Movie Database does not have a public API, an open API exists at http://www.tvmaze.com/api.
#
# Use this API to retrieve information about each of the 250 TV shows you have extracted in the previous step.
# 1. Check the documentation of tvmaze's api to learn how to request show data by id.
# - Define a function that returns a python object with select information for a given id.
#     - Show name
#     - Rating (avg)
#     - Genre(s)
#     - Network name
#     - Premiere date
#     - Status
# > Tip: the json object can easily be converted into a python dictionary.
#
# - Store the gathered information in a Pandas Dataframe.
#
# As the target information is in json format you will need `json.loads()` in order to gather it.

# %%
# A:
html=requests.get('http://api.tvmaze.com/lookup/shows?imdb=tt0944947')

# %%
import json
json.loads(html.text)
# Out:
# {'id': 82,
#  'url': 'http://www.tvmaze.com/shows/82/game-of-thrones',
#  'name': 'Game of Thrones',
#  'type': 'Scripted',
#  'language': 'English',
#  'genres': ['Drama', 'Adventure', 'Fantasy'],
#  'status': 'Running',
#  'runtime': 60,
#  'premiered': '2011-04-17',
#  'officialSite': 'http://www.hbo.com/game-of-thrones',
#  'schedule': {'time': '21:00', 'days': ['Sunday']},
#  'rating': {'average': 9.3},
#  'weight': 99,
#  'network': {'id': 8,
#   'name': 'HBO',
#   'country': {'name': 'United States',
#    'code': 'US',
#    'timezone': 'America/New_York'}},
#  'webChannel': {'id': 22,
#   'name': 'HBO Go',
#   'country': {'name': 'United States',
#    'code': 'US',
#    'timezone': 'America/New_York'}},
#  'externals': {'tvrage': 24493, 'thetvdb': 121361, 'imdb': 'tt0944947'},
#  'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/143/359013.jpg',
#   'original': 'http://static.tvmaze.com/uploads/images/original_untouched/143/359013.jpg'},
#  'summary': '<p>Based on the bestselling book series <i>A Song of Ice and Fire</i> by George R.R. Martin, this sprawling new HBO drama is set in a world where summers span decades and winters can last a lifetime. From the scheming south and the savage eastern lands, to the frozen north and ancient Wall that protects the realm from the mysterious darkness beyond, the powerful families of the Seven Kingdoms are locked in a battle for the Iron Throne. This is a story of duplicity and treachery, nobility and honor, conquest and triumph. In the <b>Game of Thrones</b>, you either win or you die.</p>',
#  'updated': 1542122562,
#  '_links': {'self': {'href': 'http://api.tvmaze.com/shows/82'},
#   'previousepisode': {'href': 'http://api.tvmaze.com/episodes/1221415'}}}

# %%
def api_to_df(final_lst):
    temp_dict={
        'name':[],
        'rating':[],
        'genre':[],
        'network_name':[],
        'premiered':[],
        'status':[],}
    for i in final_lst:
        html=requests.get('http://api.tvmaze.com/lookup/shows?imdb={}'.format(i))
        try:
            html=json.loads(html.text)
        except:
            print('ID:',i,' ','Error_type:',html,'ID not available in website')
            continue
        try:
            temp_dict['name'].append(html['name'])
        except:
            temp_dict['name'].append(None)
        try:
            temp_dict['rating'].append(html['rating']['average'])
        except:
            temp_dict['rating'].append(None)
        try:
            temp_dict['genre'].append(html['genres'])
        except:
            temp_dict['genre'].append(None)
        try:
            temp_dict['network_name'].append(html['network']['name'])
        except:
            temp_dict['network_name'].append(None)
        try:
            temp_dict['premiered'].append(html['premiered'])
        except:
            temp_dict['premiered'].append(None)
        try:
            temp_dict['status'].append(html['status'])
        except:
            temp_dict['status'].append(None)
    return pd.DataFrame(temp_dict)

# %%
df=api_to_df(final_lst)
# Out:
# ID: tt1508238   Error_type: <Response [404]> ID not available in website
# ID: tt0096548   Error_type: <Response [404]> ID not available in website
# ID: tt0121220   Error_type: <Response [404]> ID not available in website
# ID: tt0090509   Error_type: <Response [404]> ID not available in website
# ID: tt0108855   Error_type: <Response [404]> ID not available in website
# ID: tt0088484   Error_type: <Response [404]> ID not available in website
# ID: tt0092324   Error_type: <Response [404]> ID not available in website
# ID: tt0314979   Error_type: <Response [404]> ID not available in website
# ID: tt0203082   Error_type: <Response [404]> ID not available in website
# ID: tt8595766   Error_type: <Response [404]> ID not available in website
# ID: tt0088509   Error_type: <Response [404]> ID not available in website
# ID: tt4093826   Error_type: <Response [404]> ID not available in website
# ID: tt1230180   Error_type: <Response [404]> ID not available in website
# ID: tt6205862   Error_type: <Response [404]> ID not available in website
# ID: tt6328940   Error_type: <Response [404]> ID not available in website

# %%
df
# Out:
#                                    name  rating  \
# 0                       Planet Earth II     9.6
# 1                      Band of Brothers     9.3
# 2                       Game of Thrones     9.3
# 3                          Planet Earth     9.3
# 4                          Breaking Bad     9.3
# 5                              The Wire     9.3
# 6                                Cosmos     9.3
# 7                        Rick and Morty     9.4
# 8                                Cosmos    10.0
# 9                        Blue Planet II     9.4
# 10                         The Sopranos     9.2
# 11                     The World at War     NaN
# 12           Avatar: The Last Airbender     9.3
# 13                                 Life     7.5
# 14                             Sherlock     9.2
# 15                    The Twilight Zone     9.2
# 16                         Human Planet     8.5
# 17                      The Vietnam War     8.3
# 18                        The Decalogue     NaN
# 19                        The Civil War     NaN
# 20                              Firefly     9.3
# 21                       True Detective     8.2
# 22     Fullmetal Alchemist: Brotherhood     9.1
# 23                                Fargo     9.0
# 24   Last Week Tonight with John Oliver     8.8
# 25          Batman: The Animated Series     9.2
# 26                           Death Note     8.7
# 27                      The Blue Planet     9.7
# 28                         Cowboy Bebop     8.8
# 29                             Şahsiyet     NaN
# ..                                  ...     ...
# 205                              Utopia     8.6
# 206                              Borgen     8.2
# 207                           Entourage     7.9
# 208                          Doctor Who     8.9
# 209                       State of Play     NaN
# 210                       Modern Family     8.0
# 211                        Inside No. 9     8.3
# 212                     The Muppet Show     7.4
# 213                         Kardeş Payı     NaN
# 214                  Jeeves and Wooster     8.7
# 215                              Fringe     8.9
# 216                  Brooklyn Nine-Nine     8.1
# 217                 Permanent Roommates     NaN
# 218                     Who Is America?     6.8
# 219                            Billions     8.2
# 220                        Supernatural     8.4
# 221                         Broadchurch     8.6
# 222                                Lost     8.5
# 223                         The Expanse     8.7
# 224                      The Good Fight     8.3
# 225                    Olive Kitteridge     8.6
# 226                               Roots     9.3
# 227                       The Americans     8.5
# 228                           Star Trek     8.6
# 229                  Naruto: Shippuuden     8.8
# 230                       Stargate SG-1     9.3
# 231                      The Young Pope     7.5
# 232                              Scrubs     8.8
# 233                             Rectify     8.2
# 234                Anne of Green Gables     NaN
#
#                                            genre  network_name   premiered  \
# 0                                       [Nature]       BBC One  2016-11-06
# 1                           [Drama, Action, War]           HBO  2001-09-09
# 2                    [Drama, Adventure, Fantasy]           HBO  2011-04-17
# 3                                       [Nature]       BBC One  2006-03-05
# 4                       [Drama, Crime, Thriller]           AMC  2008-01-20
# 5                                 [Drama, Crime]           HBO  2002-06-02
# 6                                             []           FOX  2014-03-09
# 7           [Comedy, Adventure, Science-Fiction]    Adult Swim  2013-12-02
# 8                                             []           PBS  1980-09-28
# 9                                       [Nature]       BBC One  2017-10-29
# 10                                [Drama, Crime]           HBO  1999-01-10
# 11                                [War, History]           ITV  1973-10-31
# 12                  [Action, Adventure, Fantasy]   Nickelodeon  2005-02-21
# 13                                      [Nature]       BBC One  2009-10-12
# 14                       [Drama, Crime, Mystery]       BBC One  2010-07-25
# 15                    [Fantasy, Horror, Mystery]           CBS  1959-10-02
# 16                                      [Nature]       BBC One  2011-01-13
# 17                                [War, History]           PBS  2017-09-17
# 18                                       [Drama]          TVP1  1989-12-10
# 19                                [War, History]           PBS  1990-09-23
# 20         [Adventure, Science-Fiction, Western]           FOX  2002-09-20
# 21                      [Drama, Crime, Thriller]           HBO  2014-01-12
# 22           [Action, Adventure, Anime, Fantasy]           TBS  2009-04-05
# 23                                [Drama, Crime]            FX  2014-04-15
# 24                                      [Comedy]           HBO  2014-04-27
# 25          [Action, Adventure, Science-Fiction]           FOX  1992-09-05
# 26             [Drama, Anime, Thriller, Mystery]           NTV  2006-10-03
# 27                                      [Nature]       BBC One  2001-09-12
# 28   [Action, Adventure, Anime, Science-Fiction]         WOWOW  1998-10-24
# 29                      [Drama, Crime, Thriller]          None  2018-03-17
# ..                                           ...           ...         ...
# 205           [Drama, Science-Fiction, Thriller]     Channel 4  2013-01-15
# 206                                      [Drama]           DR1  2010-09-26
# 207                              [Drama, Comedy]           HBO  2004-07-18
# 208         [Action, Adventure, Science-Fiction]       BBC One  1963-11-23
# 209                                      [Drama]       BBC One  2003-05-18
# 210                             [Comedy, Family]           ABC  2009-09-23
# 211             [Comedy, Thriller, Supernatural]       BBC Two  2014-02-05
# 212                                     [Comedy]           CBS  1977-04-25
# 213                      [Drama, Comedy, Family]       Star TV  2014-02-13
# 214                                     [Comedy]           ITV  1990-04-22
# 215             [Drama, Action, Science-Fiction]           FOX  2008-09-09
# 216                      [Comedy, Action, Crime]           NBC  2013-09-17
# 217                     [Drama, Comedy, Romance]          None  2014-10-29
# 218                                           []      Showtime  2018-07-15
# 219                               [Drama, Crime]      Showtime  2016-01-17
# 220                [Drama, Action, Supernatural]        The CW  2005-09-13
# 221                      [Drama, Crime, Mystery]           ITV  2013-03-04
# 222             [Drama, Adventure, Supernatural]           ABC  2004-09-22
# 223         [Science-Fiction, Thriller, Mystery]          None  2015-12-14
# 224                               [Drama, Legal]          None  2017-02-19
# 225                                      [Drama]           HBO  2014-11-02
# 226                             [Drama, History]           ABC  1977-01-23
# 227                           [Drama, Espionage]            FX  2013-01-30
# 228                 [Adventure, Science-Fiction]           NBC  1966-09-08
# 229          [Action, Adventure, Anime, Fantasy]      TV Tokyo  2007-02-15
# 230         [Action, Adventure, Science-Fiction]          Syfy  1997-07-27
# 231                             [Drama, History]  Sky Atlantic  2016-10-21
# 232                     [Drama, Comedy, Medical]           ABC  2001-10-02
# 233                               [Drama, Crime]   Sundance TV  2013-04-22
# 234                              [Drama, Family]           CBC  1985-12-05
#
#                status
# 0               Ended
# 1               Ended
# 2             Running
# 3               Ended
# 4               Ended
# 5               Ended
# 6             Running
# 7             Running
# 8               Ended
# 9               Ended
# 10              Ended
# 11              Ended
# 12              Ended
# 13              Ended
# 14   To Be Determined
# 15              Ended
# 16              Ended
# 17              Ended
# 18              Ended
# 19              Ended
# 20              Ended
# 21            Running
# 22              Ended
# 23            Running
# 24            Running
# 25              Ended
# 26              Ended
# 27              Ended
# 28              Ended
# 29              Ended
# ..                ...
# 205             Ended
# 206             Ended
# 207             Ended
# 208             Ended
# 209             Ended
# 210           Running
# 211           Running
# 212             Ended
# 213             Ended
# 214             Ended
# 215             Ended
# 216           Running
# 217           Running
# 218  To Be Determined
# 219           Running
# 220           Running
# 221             Ended
# 222             Ended
# 223           Running
# 224           Running
# 225             Ended
# 226             Ended
# 227             Ended
# 228             Ended
# 229             Ended
# 230             Ended
# 231             Ended
# 232             Ended
# 233             Ended
# 234             Ended
#
# [235 rows x 6 columns]

# %%
len(df.dropna())
# Out:
# 182
